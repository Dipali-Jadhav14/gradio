# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipali-Jadhav14/gradio/blob/main/gradio109.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#gadio is a python library it helps to you to make quickly web base interface
# !pip install gradio --quiet
import gradio as gr

# %%
def greet(name):
  return f"hello,  {name}!"

# %%
demo = gr.Interface(fn=greet, inputs="text", outputs="text")
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e4e1d03b24a03c8cac.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e4e1d03b24a03c8cac.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def add_numbers(num1,num2):
    return num1+num2

# %%
import gradio as gr

# function to add two numbers
def add_numbers(a, b):
    return a + b

# Gradio interface
demo = gr.Interface(
    fn=add_numbers,
    inputs=[
        gr.Number(label="First Number"),
        gr.Number(label="Second Number")
    ],
    outputs=gr.Number(label="Sum"),
    title="Addition App",
    description="Enter two numbers and get their sum"
)

# launch app
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://0133d29e5d0ddef957.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0133d29e5d0ddef957.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

# login function
def login(username, password):
    # dummy credentials
    if username == "admin" and password == "1234":
        return " Login successful!"
    else:
        return " Invalid username or password"

# Gradio UI
demo = gr.Interface(
    fn=login,
    inputs=[
        gr.Textbox(label="Username", placeholder="Enter username"),
        gr.Textbox(label="Password", type="password", placeholder="Enter password")
    ],
    outputs=gr.Textbox(label="Status"),
    title="Login Form",
    description="Simple login form using Gradio"
)

# launch app
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ec1a5cea8b47e684bf.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ec1a5cea8b47e684bf.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

# login logic
def login(username, password):
    if username == "user" and password == "1234":
        return "<h3 style='color:green;'> Login Successful</h3>"
    else:
        return "<h3 style='color:red;'>Invalid Username or Password</h3>"

# custom CSS
custom_css = """
body {
    background: linear-gradient(120deg, #89f7fe, #66a6ff);
}
.login-box {
    background: white;
    padding: 25px;
    border-radius: 10px;
    width: 320px;
    margin: auto;
    box-shadow: 0px 10px 25px rgba(0,0,0,0.2);
}
.login-box h2 {
    text-align: center;
}
"""

with gr.Blocks(css=custom_css) as demo:
    gr.HTML("<div class='login-box'><h2>User Login</h2></div>")

    username = gr.Textbox(label="Username", placeholder="Enter username")
    password = gr.Textbox(label="Password", type="password", placeholder="Enter password")

    login_btn = gr.Button("Login")
    output = gr.HTML()

    login_btn.click(
        fn=login,
        inputs=[username, password],
        outputs=output
    )

demo.launch()
# Out:
# /tmp/ipython-input-217740786.py:28: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(css=custom_css) as demo:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://43ee0864e3baef56b9.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...

# %%
import gradio as gr

# temporary user storage
users = {}

# registration function
def register(username, password):
    if username in users:
        return "<p style='color:red;'> User already exists</p>"
    users[username] = password
    return "<p style='color:green;'> Registration successful</p>"

# login function
def login(username, password):
    if username in users and users[username] == password:
        return "<h3 style='color:green;'>🎉 Login Successful</h3>"
    return "<h3 style='color:red;'> Invalid credentials</h3>"

# custom CSS
custom_css = """
body {
    background: linear-gradient(135deg, #667eea, #764ba2);
    font-family: Arial, sans-serif;
}
.card {
    background: white;
    padding: 25px;
    border-radius: 12px;
    width: 360px;
    margin: auto;
    box-shadow: 0 15px 30px rgba(0,0,0,0.25);
}
.card h2 {
    text-align: center;
    color: #333;
}
"""

with gr.Blocks(css=custom_css) as demo:

    gr.HTML("<div class='card'><h2>User Registration</h2></div>")
    reg_user = gr.Textbox(label="Username")
    reg_pass = gr.Textbox(label="Password", type="password")
    reg_btn = gr.Button("Register")
    reg_out = gr.HTML()

    reg_btn.click(register, [reg_user, reg_pass], reg_out)

    gr.HTML("<hr>")

    gr.HTML("<div class='card'><h2>User Login</h2></div>")
    log_user = gr.Textbox(label="Username")
    log_pass = gr.Textbox(label="Password", type="password")
    log_btn = gr.Button("Login")
    log_out = gr.HTML()

    log_btn.click(login, [log_user, log_pass], log_out)

demo.launch()
# Out:
# /tmp/ipython-input-2196229045.py:39: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(css=custom_css) as demo:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://99efc29c508f99884d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...

# %%
import gradio as gr

def attendance(percent):
  if percent>75:
    return "Eligible for Exam"
  return "Not Eligible for Exam"

gr.Interface(
    fn=attendance,
    inputs=gr.Slider(0,100,step=1,label="Attendance %"),
    outputs="text",
    title="Attendance Checker"
).launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://fa12db4a11d7fc48b5.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fa12db4a11d7fc48b5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
def image_info(img):
  return "Image Upload Successfully"

gr.Interface(
    fn=image_info,
    inputs=gr.Image(label="Upload an Image"),
    outputs="text"
).launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9f2578a18df710b28e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9f2578a18df710b28e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
def reg_user(name,email,dob,imag):
  if image is None:
      return "Image Upload Failed"
  return f"Registered: {name}, {email}, {dob} (Image Uploaded)"

with gr.Blocks() as demo:
    gr.Markdown("User Registration Form")

    name = gr.Textbox(label="Full Name",placeholder="Enter Full Name")
    email = gr.Textbox(label="Email",placeholder="Enter Email")
    dob = gr.Textbox(label="Date of Birth(yyyy-mm-dd)")
    image = gr.Image(label="upload images",type="numpy")

    submit = gr.Button("Submit")
    output= gr.Textbox(label="Result")

    submit.click(
        fn=reg_user,
        inputs=[name,email,dob,image],
        outputs=output
    )
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://6d6e383232fe9221a4.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6d6e383232fe9221a4.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
